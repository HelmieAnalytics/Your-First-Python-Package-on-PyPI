# %% [markdown]
# <a href="https://colab.research.google.com/github/HelmieAnalytics/Your-First-Python-Package-on-PyPI/blob/main/Momentum_Ranking_Model_revised4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Install packages

# %%
# !pip install yfinance

# %%
# !pip install yahooquery

# %%
# !pip install stockstats

# %%
# !pip install mpld3

# %% [markdown]
# ###Install and run XarData v0.1.0

# %%
# !pip install -i https://test.pypi.org/simple/ xardata

# %%
import pandas as pd
import xardata
from xardata import jse_tickers as jt
from xardata import jse_data as jd
from xardata import process_data as jpd

my_access_key = 'e52cf3b93696352e880916f8c8adbf0c'

tickers = jt.get_tickers(my_access_key)

symbols = tickers
start = '2023-07-01'
end = '2024-07-04'

output_folder_path = '/content/jsestocks'

jd.get_data(symbols, start, end, output_folder_path)

jpd.clean('/content/jsestocks')

# %% [markdown]
# ###Delete files in directories

# %%
import os
import glob

# Base directory containing the folders
base_dir = '/content/'
exclude_subdir = 'drive'  # Name of the subdirectory to exclude

# Find all subdirectories within the base directory
subdirs = [d for d in glob.glob(os.path.join(base_dir, '*')) if os.path.isdir(d)]

# Iterate over each subdirectory and delete all files within them, except the excluded subdirectory
for subdir in subdirs:
    if os.path.basename(subdir) == exclude_subdir:
        continue  # Skip the excluded subdirectory
    files = glob.glob(os.path.join(subdir, '*'))  # Get all files in the subdirectory
    for file in files:
        try:
            os.remove(file)  # Delete the file
            print(f"Deleted {file}")
        except Exception as e:
            print(f"Error deleting {file}: {e}")
# Out:
# Deleted /content/ranking_table/WEZ.JO.csv
# Deleted /content/ranking_table/RHB.JO.csv
# Deleted /content/ranking_table/SNV.JO.csv
# Deleted /content/ranking_table/PPE.JO.csv
# Deleted /content/ranking_table/KIO.JO.csv
# Deleted /content/ranking_table/AME.JO.csv
# Deleted /content/ranking_table/GPL.JO.csv
# Deleted /content/ranking_table/JSE.JO.csv
# Deleted /content/ranking_table/AFH.JO.csv
# Deleted /content/ranking_table/TRU.JO.csv
# Deleted /content/ranking_table/APH.JO.csv
# Deleted /content/ranking_table/GLN.JO.csv
# Deleted /content/ranking_table/SUR.JO.csv
# Deleted /content/ranking_table/PBG.JO.csv
# Deleted /content/ranking_table/MMP.JO.csv
# Deleted /content/ranking_table/SYG.JO.csv
# Deleted /content/ranking_table/TRE.JO.csv
# Deleted /content/ranking_table/TKG.JO.csv
# Deleted /content/ranking_table/RNG.JO.csv
# Deleted /content/ranking_table/DSBP.JO.csv
# Deleted /content/ranking_table/NPN.JO.csv
# Deleted /content/ranking_table/SNT.JO.csv
# Deleted /content/ranking_table/GSH.JO.csv
# Deleted /content/ranking_table/ZED.JO.csv
# Deleted /content/ranking_table/NTCP.JO.csv
# Deleted /content/ranking_table/KAP.JO.csv
# Deleted /content/ranking_table/AFT.JO.csv
# Deleted /content/ranking_table/BAW.JO.csv
# Deleted /content/ranking_table/SBPP.JO.csv
# Deleted /content/ranking_table/CTA.JO.csv
# Deleted /content/ranking_table/ISB.JO.csv
# Deleted /content/ranking_table/AEL.JO.csv
# Deleted /content/ranking_table/SSK.JO.csv
# Deleted /content/ranking_table/BLU.JO.csv
# Deleted /content/ranking_table/MDI.JO.csv
# Deleted /content/ranking_table/KAL.JO.csv
# Deleted /content/ranking_table/BRN.JO.csv
# Deleted /content/ranking_table/CLI.JO.csv
# Deleted /content/ranking_table/CSB.JO.csv
# Deleted /content/ranking_table/4SI.JO.csv
# Deleted /content/ranking_table/RMH.JO.csv
# Deleted /content/ranking_table/CLS.JO.csv
# Deleted /content/ranking_table/CMH.JO.csv
# Deleted /content/ranking_table/SLM.JO.csv
# Deleted /content/ranking_table/ABSP.JO.csv
# Deleted /content/ranking_table/OCE.JO.csv
# Deleted /content/ranking_table/SEA.JO.csv
# Deleted /content/ranking_table/AIP.JO.csv
# Deleted /content/ranking_table/SPG.JO.csv
# Deleted /content/ranking_table/APN.JO.csv
# Deleted /content/ranking_table/BVT.JO.csv
# Deleted /content/ranking_table/LEW.JO.csv
# Deleted /content/ranking_table/MRP.JO.csv
# Deleted /content/ranking_table/HDC.JO.csv
# Deleted /content/ranking_table/BID.JO.csv
# Deleted /content/ranking_table/SPP.JO.csv
# Deleted /content/ranking_table/QLT.JO.csv
# Deleted /content/ranking_table/NWL.JO.csv
# Deleted /content/ranking_table/DCP.JO.csv
# Deleted /content/ranking_table/SHP.JO.csv
# Deleted /content/ranking_table/YYLBEE.JO.csv
# Deleted /content/ranking_table/MPT.JO.csv
# Deleted /content/ranking_table/TEX.JO.csv
# Deleted /content/ranking_table/YRK.JO.csv
# Deleted /content/ranking_table/TRL.JO.csv
# Deleted /content/ranking_table/ACT.JO.csv
# Deleted /content/ranking_table/DLT.JO.csv
# Deleted /content/ranking_table/THA.JO.csv
# Deleted /content/ranking_table/NVS.JO.csv
# Deleted /content/ranking_table/CGR.JO.csv
# Deleted /content/momentum_stocks/WEZ.JO.csv
# Deleted /content/momentum_stocks/RHB.JO.csv
# Deleted /content/momentum_stocks/SNV.JO.csv
# Deleted /content/momentum_stocks/PPE.JO.csv
# Deleted /content/momentum_stocks/KIO.JO.csv
# Deleted /content/momentum_stocks/AME.JO.csv
# Deleted /content/momentum_stocks/GPL.JO.csv
# Deleted /content/momentum_stocks/JSE.JO.csv
# Deleted /content/momentum_stocks/AFH.JO.csv
# Deleted /content/momentum_stocks/TRU.JO.csv
# Deleted /content/momentum_stocks/APH.JO.csv
# Deleted /content/momentum_stocks/GLN.JO.csv
# Deleted /content/momentum_stocks/SUR.JO.csv
# Deleted /content/momentum_stocks/PBG.JO.csv
# Deleted /content/momentum_stocks/MMP.JO.csv
# Deleted /content/momentum_stocks/SYG.JO.csv
# Deleted /content/momentum_stocks/TRE.JO.csv
# Deleted /content/momentum_stocks/TKG.JO.csv
# Deleted /content/momentum_stocks/RNG.JO.csv
# Deleted /content/momentum_stocks/DSBP.JO.csv
# Deleted /content/momentum_stocks/NPN.JO.csv
# Deleted /content/momentum_stocks/SNT.JO.csv
# Deleted /content/momentum_stocks/GSH.JO.csv
# Deleted /content/momentum_stocks/ZED.JO.csv
# Deleted /content/momentum_stocks/NTCP.JO.csv
# Deleted /content/momentum_stocks/KAP.JO.csv
# Deleted /content/momentum_stocks/AFT.JO.csv
# Deleted /content/momentum_stocks/BAW.JO.csv
# Deleted /content/momentum_stocks/SBPP.JO.csv
# Deleted /content/momentum_stocks/CTA.JO.csv
# Deleted /content/momentum_stocks/ISB.JO.csv
# Deleted /content/momentum_stocks/AEL.JO.csv
# Deleted /content/momentum_stocks/SSK.JO.csv
# Deleted /content/momentum_stocks/BLU.JO.csv
# Deleted /content/momentum_stocks/MDI.JO.csv
# Deleted /content/momentum_stocks/KAL.JO.csv
# Deleted /content/momentum_stocks/BRN.JO.csv
# Deleted /content/momentum_stocks/CLI.JO.csv
# Deleted /content/momentum_stocks/CSB.JO.csv
# Deleted /content/momentum_stocks/4SI.JO.csv
# Deleted /content/momentum_stocks/RMH.JO.csv
# Deleted /content/momentum_stocks/CLS.JO.csv
# Deleted /content/momentum_stocks/CMH.JO.csv
# Deleted /content/momentum_stocks/SLM.JO.csv
# Deleted /content/momentum_stocks/ABSP.JO.csv
# Deleted /content/momentum_stocks/OCE.JO.csv
# Deleted /content/momentum_stocks/SEA.JO.csv
# Deleted /content/momentum_stocks/AIP.JO.csv
# Deleted /content/momentum_stocks/SPG.JO.csv
# Deleted /content/momentum_stocks/APN.JO.csv
# Deleted /content/momentum_stocks/BVT.JO.csv
# Deleted /content/momentum_stocks/LEW.JO.csv
# Deleted /content/momentum_stocks/MRP.JO.csv
# Deleted /content/momentum_stocks/HDC.JO.csv
# Deleted /content/momentum_stocks/BID.JO.csv
# Deleted /content/momentum_stocks/SPP.JO.csv
# Deleted /content/momentum_stocks/QLT.JO.csv
# Deleted /content/momentum_stocks/NWL.JO.csv
# Deleted /content/momentum_stocks/DCP.JO.csv
# Deleted /content/momentum_stocks/SHP.JO.csv
# Deleted /content/momentum_stocks/YYLBEE.JO.csv
# Deleted /content/momentum_stocks/MPT.JO.csv
# Deleted /content/momentum_stocks/TEX.JO.csv
# Deleted /content/momentum_stocks/YRK.JO.csv
# Deleted /content/momentum_stocks/TRL.JO.csv
# Deleted /content/momentum_stocks/ACT.JO.csv
# Deleted /content/momentum_stocks/DLT.JO.csv
# Deleted /content/momentum_stocks/THA.JO.csv
# Deleted /content/momentum_stocks/NVS.JO.csv
# Deleted /content/momentum_stocks/CGR.JO.csv
# Deleted /content/momentum_tickers/WEZ.JO.csv
# Deleted /content/momentum_tickers/RHB.JO.csv
# Deleted /content/momentum_tickers/SNV.JO.csv
# Deleted /content/momentum_tickers/PPE.JO.csv
# Deleted /content/momentum_tickers/KIO.JO.csv
# Deleted /content/momentum_tickers/AME.JO.csv
# Deleted /content/momentum_tickers/GPL.JO.csv
# Deleted /content/momentum_tickers/JSE.JO.csv
# Deleted /content/momentum_tickers/AFH.JO.csv
# Deleted /content/momentum_tickers/TRU.JO.csv
# Deleted /content/momentum_tickers/APH.JO.csv
# Deleted /content/momentum_tickers/GLN.JO.csv
# Deleted /content/momentum_tickers/SUR.JO.csv
# Deleted /content/momentum_tickers/PBG.JO.csv
# Deleted /content/momentum_tickers/MMP.JO.csv
# Deleted /content/momentum_tickers/SYG.JO.csv
# Deleted /content/momentum_tickers/TRE.JO.csv
# Deleted /content/momentum_tickers/TKG.JO.csv
# Deleted /content/momentum_tickers/RNG.JO.csv
# Deleted /content/momentum_tickers/DSBP.JO.csv
# Deleted /content/momentum_tickers/NPN.JO.csv
# Deleted /content/momentum_tickers/SNT.JO.csv
# Deleted /content/momentum_tickers/GSH.JO.csv
# Deleted /content/momentum_tickers/ZED.JO.csv
# Deleted /content/momentum_tickers/NTCP.JO.csv
# Deleted /content/momentum_tickers/KAP.JO.csv
# Deleted /content/momentum_tickers/AFT.JO.csv
# Deleted /content/momentum_tickers/BAW.JO.csv
# Deleted /content/momentum_tickers/SBPP.JO.csv
# Deleted /content/momentum_tickers/CTA.JO.csv
# Deleted /content/momentum_tickers/ISB.JO.csv
# Deleted /content/momentum_tickers/AEL.JO.csv
# Deleted /content/momentum_tickers/SSK.JO.csv
# Deleted /content/momentum_tickers/BLU.JO.csv
# Deleted /content/momentum_tickers/MDI.JO.csv
# Deleted /content/momentum_tickers/KAL.JO.csv
# Deleted /content/momentum_tickers/BRN.JO.csv
# Deleted /content/momentum_tickers/CLI.JO.csv
# Deleted /content/momentum_tickers/CSB.JO.csv
# Deleted /content/momentum_tickers/4SI.JO.csv
# Deleted /content/momentum_tickers/RMH.JO.csv
# Deleted /content/momentum_tickers/CLS.JO.csv
# Deleted /content/momentum_tickers/CMH.JO.csv
# Deleted /content/momentum_tickers/SLM.JO.csv
# Deleted /content/momentum_tickers/ABSP.JO.csv
# Deleted /content/momentum_tickers/OCE.JO.csv
# Deleted /content/momentum_tickers/SEA.JO.csv
# Deleted /content/momentum_tickers/AIP.JO.csv
# Deleted /content/momentum_tickers/SPG.JO.csv
# Deleted /content/momentum_tickers/APN.JO.csv
# Deleted /content/momentum_tickers/BVT.JO.csv
# Deleted /content/momentum_tickers/LEW.JO.csv
# Deleted /content/momentum_tickers/MRP.JO.csv
# Deleted /content/momentum_tickers/HDC.JO.csv
# Deleted /content/momentum_tickers/BID.JO.csv
# Deleted /content/momentum_tickers/SPP.JO.csv
# Deleted /content/momentum_tickers/QLT.JO.csv
# Deleted /content/momentum_tickers/NWL.JO.csv
# Deleted /content/momentum_tickers/DCP.JO.csv
# Deleted /content/momentum_tickers/SHP.JO.csv
# Deleted /content/momentum_tickers/YYLBEE.JO.csv
# Deleted /content/momentum_tickers/MPT.JO.csv
# Deleted /content/momentum_tickers/TEX.JO.csv
# Deleted /content/momentum_tickers/YRK.JO.csv
# Deleted /content/momentum_tickers/TRL.JO.csv
# Deleted /content/momentum_tickers/ACT.JO.csv
# Deleted /content/momentum_tickers/DLT.JO.csv
# Deleted /content/momentum_tickers/THA.JO.csv
# Deleted /content/momentum_tickers/NVS.JO.csv
# Deleted /content/momentum_tickers/CGR.JO.csv
# Deleted /content/jsestocks/GRT.JO.csv
# Deleted /content/jsestocks/REB.JO.csv
# Deleted /content/jsestocks/KST.JO.csv
# Deleted /content/jsestocks/WEZ.JO.csv
# Deleted /content/jsestocks/RHB.JO.csv
# Deleted /content/jsestocks/PSV.JO.csv
# Deleted /content/jsestocks/VKE.JO.csv
# Deleted /content/jsestocks/WBO.JO.csv
# Deleted /content/jsestocks/SNV.JO.csv
# Deleted /content/jsestocks/PPR.JO.csv
# Deleted /content/jsestocks/VUN.JO.csv
# Deleted /content/jsestocks/CML.JO.csv
# Deleted /content/jsestocks/AMIB50.JO.csv
# Deleted /content/jsestocks/NRP.JO.csv
# Deleted /content/jsestocks/PPE.JO.csv
# Deleted /content/jsestocks/EPE.JO.csv
# Deleted /content/jsestocks/ACS.JO.csv
# Deleted /content/jsestocks/KIO.JO.csv
# Deleted /content/jsestocks/AME.JO.csv
# Deleted /content/jsestocks/RAV.JO.csv
# Deleted /content/jsestocks/NTC.JO.csv
# Deleted /content/jsestocks/BAT.JO.csv
# Deleted /content/jsestocks/AFEP.JO.csv
# Deleted /content/jsestocks/TLM.JO.csv
# Deleted /content/jsestocks/SSW.JO.csv
# Deleted /content/jsestocks/GPL.JO.csv
# Deleted /content/jsestocks/NED.JO.csv
# Deleted /content/jsestocks/ADH.JO.csv
# Deleted /content/jsestocks/JSE.JO.csv
# Deleted /content/jsestocks/CPI.JO.csv
# Deleted /content/jsestocks/WKF.JO.csv
# Deleted /content/jsestocks/ARL.JO.csv
# Deleted /content/jsestocks/AFH.JO.csv
# Deleted /content/jsestocks/GML.JO.csv
# Deleted /content/jsestocks/VIS.JO.csv
# Deleted /content/jsestocks/HCI.JO.csv
# Deleted /content/jsestocks/TRU.JO.csv
# Deleted /content/jsestocks/APH.JO.csv
# Deleted /content/jsestocks/IVT.JO.csv
# Deleted /content/jsestocks/EUZ.JO.csv
# Deleted /content/jsestocks/GLN.JO.csv
# Deleted /content/jsestocks/SUR.JO.csv
# Deleted /content/jsestocks/ACL.JO.csv
# Deleted /content/jsestocks/HIL.JO.csv
# Deleted /content/jsestocks/SUI.JO.csv
# Deleted /content/jsestocks/PBG.JO.csv
# Deleted /content/jsestocks/MMP.JO.csv
# Deleted /content/jsestocks/JBL.JO.csv
# Deleted /content/jsestocks/SYG.JO.csv
# Deleted /content/jsestocks/AHL.JO.csv
# Deleted /content/jsestocks/FGL.JO.csv
# Deleted /content/jsestocks/TSG.JO.csv
# Deleted /content/jsestocks/TPC.JO.csv
# Deleted /content/jsestocks/TRE.JO.csv
# Deleted /content/jsestocks/TKG.JO.csv
# Deleted /content/jsestocks/RNG.JO.csv
# Deleted /content/jsestocks/LTE.JO.csv
# Deleted /content/jsestocks/FSR.JO.csv
# Deleted /content/jsestocks/DSBP.JO.csv
# Deleted /content/jsestocks/GNDP.JO.csv
# Deleted /content/jsestocks/NPN.JO.csv
# Deleted /content/jsestocks/SFN.JO.csv
# Deleted /content/jsestocks/RFG.JO.csv
# Deleted /content/jsestocks/PPH.JO.csv
# Deleted /content/jsestocks/DTC.JO.csv
# Deleted /content/jsestocks/SNT.JO.csv
# Deleted /content/jsestocks/GSH.JO.csv
# Deleted /content/jsestocks/PMV.JO.csv
# Deleted /content/jsestocks/IVTP.JO.csv
# Deleted /content/jsestocks/MTH.JO.csv
# Deleted /content/jsestocks/ART.JO.csv
# Deleted /content/jsestocks/WHL.JO.csv
# Deleted /content/jsestocks/PEM.JO.csv
# Deleted /content/jsestocks/TTO.JO.csv
# Deleted /content/jsestocks/MCG.JO.csv
# Deleted /content/jsestocks/LAB.JO.csv
# Deleted /content/jsestocks/BEL.JO.csv
# Deleted /content/jsestocks/ZED.JO.csv
# Deleted /content/jsestocks/KBO.JO.csv
# Deleted /content/jsestocks/INL.JO.csv
# Deleted /content/jsestocks/NTCP.JO.csv
# Deleted /content/jsestocks/EMN.JO.csv
# Deleted /content/jsestocks/OAO.JO.csv
# Deleted /content/jsestocks/ASC.JO.csv
# Deleted /content/jsestocks/EEL.JO.csv
# Deleted /content/jsestocks/KAP.JO.csv
# Deleted /content/jsestocks/HET.JO.csv
# Deleted /content/jsestocks/REN.JO.csv
# Deleted /content/jsestocks/MTNZF.JO.csv
# Deleted /content/jsestocks/EPS.JO.csv
# Deleted /content/jsestocks/SCD.JO.csv
# Deleted /content/jsestocks/PIK.JO.csv
# Deleted /content/jsestocks/ISA.JO.csv
# Deleted /content/jsestocks/ADR.JO.csv
# Deleted /content/jsestocks/CND.JO.csv
# Deleted /content/jsestocks/APF.JO.csv
# Deleted /content/jsestocks/AFT.JO.csv
# Deleted /content/jsestocks/HAR.JO.csv
# Deleted /content/jsestocks/SAP.JO.csv
# Deleted /content/jsestocks/BAW.JO.csv
# Deleted /content/jsestocks/TBS.JO.csv
# Deleted /content/jsestocks/CAT.JO.csv
# Deleted /content/jsestocks/SAC.JO.csv
# Deleted /content/jsestocks/MFL.JO.csv
# Deleted /content/jsestocks/DRD.JO.csv
# Deleted /content/jsestocks/tickers.csv
# Deleted /content/jsestocks/GLI.JO.csv
# Deleted /content/jsestocks/AIL.JO.csv
# Deleted /content/jsestocks/RTN.JO.csv
# Deleted /content/jsestocks/SBPP.JO.csv
# Deleted /content/jsestocks/ABG.JO.csv
# Deleted /content/jsestocks/CTA.JO.csv
# Deleted /content/jsestocks/GFI.JO.csv
# Deleted /content/jsestocks/ISB.JO.csv
# Deleted /content/jsestocks/FBR.JO.csv
# Deleted /content/jsestocks/CPIP.JO.csv
# Deleted /content/jsestocks/AEL.JO.csv
# Deleted /content/jsestocks/NPK.JO.csv
# Deleted /content/jsestocks/RTO.JO.csv
# Deleted /content/jsestocks/ARA.JO.csv
# Deleted /content/jsestocks/RNI.JO.csv
# Deleted /content/jsestocks/SSK.JO.csv
# Deleted /content/jsestocks/BLU.JO.csv
# Deleted /content/jsestocks/PRX.JO.csv
# Deleted /content/jsestocks/AYO.JO.csv
# Deleted /content/jsestocks/HUG.JO.csv
# Deleted /content/jsestocks/INPPR.JO.csv
# Deleted /content/jsestocks/AGL.JO.csv
# Deleted /content/jsestocks/DIB.JO.csv
# Deleted /content/jsestocks/MDI.JO.csv
# Deleted /content/jsestocks/KAL.JO.csv
# Deleted /content/jsestocks/FFB.JO.csv
# Deleted /content/jsestocks/GTC.JO.csv
# Deleted /content/jsestocks/BRN.JO.csv
# Deleted /content/jsestocks/CLI.JO.csv
# Deleted /content/jsestocks/ADW.JO.csv
# Deleted /content/jsestocks/ITE.JO.csv
# Deleted /content/jsestocks/AOO.JO.csv
# Deleted /content/jsestocks/CGN.JO.csv
# Deleted /content/jsestocks/NPKP.JO.csv
# Deleted /content/jsestocks/INPP.JO.csv
# Deleted /content/jsestocks/RBX.JO.csv
# Deleted /content/jsestocks/CATP.JO.csv
# Deleted /content/jsestocks/MTA.JO.csv
# Deleted /content/jsestocks/S32.JO.csv
# Deleted /content/jsestocks/CSB.JO.csv
# Deleted /content/jsestocks/QFH.JO.csv
# Deleted /content/jsestocks/REM.JO.csv
# Deleted /content/jsestocks/EOH.JO.csv
# Deleted /content/jsestocks/4SI.JO.csv
# Deleted /content/jsestocks/OCT.JO.csv
# Deleted /content/jsestocks/SSS.JO.csv
# Deleted /content/jsestocks/AFE.JO.csv
# Deleted /content/jsestocks/MCZ.JO.csv
# Deleted /content/jsestocks/MSP.JO.csv
# Deleted /content/jsestocks/RMH.JO.csv
# Deleted /content/jsestocks/SOL.JO.csv
# Deleted /content/jsestocks/ENX.JO.csv
# Deleted /content/jsestocks/KP2.JO.csv
# Deleted /content/jsestocks/MUR.JO.csv
# Deleted /content/jsestocks/ANG.JO.csv
# Deleted /content/jsestocks/AMS.JO.csv
# Deleted /content/jsestocks/EQU.JO.csv
# Deleted /content/jsestocks/CLS.JO.csv
# Deleted /content/jsestocks/CMH.JO.csv
# Deleted /content/jsestocks/DNB.JO.csv
# Deleted /content/jsestocks/SRE.JO.csv
# Deleted /content/jsestocks/SLM.JO.csv
# Deleted /content/jsestocks/ABSP.JO.csv
# Deleted /content/jsestocks/OCE.JO.csv
# Deleted /content/jsestocks/INPR.JO.csv
# Deleted /content/jsestocks/TMT.JO.csv
# Deleted /content/jsestocks/CFR.JO.csv
# Deleted /content/jsestocks/NCS.JO.csv
# Deleted /content/jsestocks/SEA.JO.csv
# Deleted /content/jsestocks/MRF.JO.csv
# Deleted /content/jsestocks/SDO.JO.csv
# Deleted /content/jsestocks/RCL.JO.csv
# Deleted /content/jsestocks/HMN.JO.csv
# Deleted /content/jsestocks/MTN.JO.csv
# Deleted /content/jsestocks/LBR.JO.csv
# Deleted /content/jsestocks/AIP.JO.csv
# Deleted /content/jsestocks/SEB.JO.csv
# Deleted /content/jsestocks/HLM.JO.csv
# Deleted /content/jsestocks/CLH.JO.csv
# Deleted /content/jsestocks/EXX.JO.csv
# Deleted /content/jsestocks/CRP.JO.csv
# Deleted /content/jsestocks/SPG.JO.csv
# Deleted /content/jsestocks/APN.JO.csv
# Deleted /content/jsestocks/BWN.JO.csv
# Deleted /content/jsestocks/SBK.JO.csv
# Deleted /content/jsestocks/ATT.JO.csv
# Deleted /content/jsestocks/RES.JO.csv
# Deleted /content/jsestocks/TFG.JO.csv
# Deleted /content/jsestocks/BTI.JO.csv
# Deleted /content/jsestocks/BVT.JO.csv
# Deleted /content/jsestocks/AVI.JO.csv
# Deleted /content/jsestocks/HYP.JO.csv
# Deleted /content/jsestocks/ARI.JO.csv
# Deleted /content/jsestocks/NRL.JO.csv
# Deleted /content/jsestocks/MTM.JO.csv
# Deleted /content/jsestocks/BRT.JO.csv
# Deleted /content/jsestocks/LEW.JO.csv
# Deleted /content/jsestocks/MRP.JO.csv
# Deleted /content/jsestocks/HDC.JO.csv
# Deleted /content/jsestocks/BID.JO.csv
# Deleted /content/jsestocks/EXP.JO.csv
# Deleted /content/jsestocks/SOH.JO.csv
# Deleted /content/jsestocks/CMO.JO.csv
# Deleted /content/jsestocks/EMH.JO.csv
# Deleted /content/jsestocks/CKS.JO.csv
# Deleted /content/jsestocks/VOD.JO.csv
# Deleted /content/jsestocks/SPP.JO.csv
# Deleted /content/jsestocks/QLT.JO.csv
# Deleted /content/jsestocks/COH.JO.csv
# Deleted /content/jsestocks/NWL.JO.csv
# Deleted /content/jsestocks/DCP.JO.csv
# Deleted /content/jsestocks/SHP.JO.csv
# Deleted /content/jsestocks/SHG.JO.csv
# Deleted /content/jsestocks/SOLBE1.JO.csv
# Deleted /content/jsestocks/IMP.JO.csv
# Deleted /content/jsestocks/ELI.JO.csv
# Deleted /content/jsestocks/REA.JO.csv
# Deleted /content/jsestocks/ORN.JO.csv
# Deleted /content/jsestocks/YYLBEE.JO.csv
# Deleted /content/jsestocks/LNF.JO.csv
# Deleted /content/jsestocks/SBKP.JO.csv
# Deleted /content/jsestocks/AEG.JO.csv
# Deleted /content/jsestocks/ANH.JO.csv
# Deleted /content/jsestocks/MPT.JO.csv
# Deleted /content/jsestocks/TCP.JO.csv
# Deleted /content/jsestocks/MNP.JO.csv
# Deleted /content/jsestocks/MST.JO.csv
# Deleted /content/jsestocks/TEX.JO.csv
# Deleted /content/jsestocks/YRK.JO.csv
# Deleted /content/jsestocks/INP.JO.csv
# Deleted /content/jsestocks/TON.JO.csv
# Deleted /content/jsestocks/EMI.JO.csv
# Deleted /content/jsestocks/SEP.JO.csv
# Deleted /content/jsestocks/RACP.JO.csv
# Deleted /content/jsestocks/GND.JO.csv
# Deleted /content/jsestocks/TRL.JO.csv
# Deleted /content/jsestocks/ACT.JO.csv
# Deleted /content/jsestocks/RLO.JO.csv
# Deleted /content/jsestocks/LHC.JO.csv
# Deleted /content/jsestocks/BCF.JO.csv
# Deleted /content/jsestocks/DLT.JO.csv
# Deleted /content/jsestocks/OMU.JO.csv
# Deleted /content/jsestocks/THA.JO.csv
# Deleted /content/jsestocks/AON.JO.csv
# Deleted /content/jsestocks/DSY.JO.csv
# Deleted /content/jsestocks/SAR.JO.csv
# Deleted /content/jsestocks/NVS.JO.csv
# Deleted /content/jsestocks/RDF.JO.csv
# Deleted /content/jsestocks/OMN.JO.csv
# Deleted /content/jsestocks/PAN.JO.csv
# Deleted /content/jsestocks/PPC.JO.csv
# Deleted /content/jsestocks/CGR.JO.csv

# %% [markdown]
# ###Modules and settings

# %%
# %matplotlib inline
import datetime
from datetime import date
import pandas as pd
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from pathlib import Path
import pandas as pd
import numpy as np
from scipy import stats
import mpld3
mpld3.enable_notebook()
"""
Settings
"""
portfolio_value = 155164.96
perf_last_month = 151728.55
start = "2023-07-01"
end = "2024-07-04"
ranking_day = "2024-07-03"
index_date = 'STXCAP_2024-07-04.csv'
ranking_table ="ranking_table_2024-07-04.csv"
portfolio = "portfolio_2024-07-04.csv"
current_portfolio = "portfolio_2024-07-04.csv"

# Storing today's date into a variable
today = date.today()
# Storing the specific date
trading_day = today
# Calculate percent difference since last month
perf_pct = (portfolio_value / perf_last_month) - 1
# Print performance, format as percent with two decimals.
print("{} - Last Month Result: {:.2%}".format(trading_day, perf_pct))
# Remember today's portfolio value for next month's calculation
#perf_last_month = portfolio_value
# Out:
# 2024-07-05 - Last Month Result: 2.26%

# %% [markdown]
# ###Import Market Data

# %%
import os

# Path to the folder containing the CSV files
folder_path = '/content/jsestocks'

# List to store the CSV file names without the .csv extension
tickers = []

# Iterate over all files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        # Remove the .csv extension and add to the list
        tickers.append(filename[:-4])

print(tickers)

#resetindex = data.reset_index(inplace = True)

# new dataframe with different column order
#df_new = data.iloc[:, [1, 2, 3, 4, 5, 6, 0]]

#Tickers = df_new["symbol"].tolist()
mylist = list(dict.fromkeys(tickers))
df = pd.DataFrame (mylist, columns = ['tickers'])
df.columns = df.iloc[1]

df.to_csv('/content/jsestocks/tickers.csv')

print('tickers')
df
# Out:
# ['GRT.JO', 'REB.JO', 'KST.JO', 'WEZ.JO', 'RHB.JO', 'PSV.JO', 'VKE.JO', 'WBO.JO', 'SNV.JO', 'PPR.JO', 'VUN.JO', 'CML.JO', 'AMIB50.JO', 'NRP.JO', 'PPE.JO', 'EPE.JO', 'ACS.JO', 'KIO.JO', 'AME.JO', 'RAV.JO', 'NTC.JO', 'BAT.JO', 'AFEP.JO', 'TLM.JO', 'SSW.JO', 'GPL.JO', 'NED.JO', 'ADH.JO', 'JSE.JO', 'CPI.JO', 'WKF.JO', 'ARL.JO', 'AFH.JO', 'GML.JO', 'VIS.JO', 'HCI.JO', 'TRU.JO', 'APH.JO', 'IVT.JO', 'EUZ.JO', 'GLN.JO', 'SUR.JO', 'ACL.JO', 'HIL.JO', 'SUI.JO', 'PBG.JO', 'MMP.JO', 'JBL.JO', 'SYG.JO', 'AHL.JO', 'FGL.JO', 'TSG.JO', 'TPC.JO', 'TRE.JO', 'TKG.JO', 'RNG.JO', 'LTE.JO', 'FSR.JO', 'DSBP.JO', 'GNDP.JO', 'NPN.JO', 'SFN.JO', 'RFG.JO', 'PPH.JO', 'DTC.JO', 'SNT.JO', 'GSH.JO', 'PMV.JO', 'IVTP.JO', 'MTH.JO', 'ART.JO', 'WHL.JO', 'PEM.JO', 'TTO.JO', 'MCG.JO', 'LAB.JO', 'BEL.JO', 'ZED.JO', 'KBO.JO', 'INL.JO', 'NTCP.JO', 'EMN.JO', 'OAO.JO', 'ASC.JO', 'EEL.JO', 'KAP.JO', 'HET.JO', 'REN.JO', 'MTNZF.JO', 'EPS.JO', 'SCD.JO', 'PIK.JO', 'ISA.JO', 'ADR.JO', 'CND.JO', 'APF.JO', 'AFT.JO', 'HAR.JO', 'SAP.JO', 'BAW.JO', 'TBS.JO', 'CAT.JO', 'SAC.JO', 'MFL.JO', 'DRD.JO', 'GLI.JO', 'AIL.JO', 'RTN.JO', 'SBPP.JO', 'ABG.JO', 'CTA.JO', 'GFI.JO', 'ISB.JO', 'FBR.JO', 'CPIP.JO', 'AEL.JO', 'NPK.JO', 'RTO.JO', 'ARA.JO', 'RNI.JO', 'SSK.JO', 'BLU.JO', 'PRX.JO', 'AYO.JO', 'HUG.JO', 'INPPR.JO', 'AGL.JO', 'DIB.JO', 'MDI.JO', 'KAL.JO', 'FFB.JO', 'GTC.JO', 'BRN.JO', 'CLI.JO', 'ADW.JO', 'ITE.JO', 'AOO.JO', 'CGN.JO', 'NPKP.JO', 'INPP.JO', 'RBX.JO', 'CATP.JO', 'MTA.JO', 'S32.JO', 'CSB.JO', 'QFH.JO', 'REM.JO', 'EOH.JO', '4SI.JO', 'OCT.JO', 'SSS.JO', 'AFE.JO', 'MCZ.JO', 'MSP.JO', 'RMH.JO', 'SOL.JO', 'ENX.JO', 'KP2.JO', 'MUR.JO', 'ANG.JO', 'AMS.JO', 'EQU.JO', 'CLS.JO', 'CMH.JO', 'DNB.JO', 'SRE.JO', 'SLM.JO', 'ABSP.JO', 'OCE.JO', 'INPR.JO', 'TMT.JO', 'CFR.JO', 'NCS.JO', 'SEA.JO', 'MRF.JO', 'SDO.JO', 'RCL.JO', 'HMN.JO', 'MTN.JO', 'LBR.JO', 'AIP.JO', 'SEB.JO', 'HLM.JO', 'CLH.JO', 'EXX.JO', 'CRP.JO', 'SPG.JO', 'APN.JO', 'BWN.JO', 'SBK.JO', 'ATT.JO', 'RES.JO', 'TFG.JO', 'BTI.JO', 'BVT.JO', 'AVI.JO', 'HYP.JO', 'ARI.JO', 'NRL.JO', 'MTM.JO', 'BRT.JO', 'LEW.JO', 'MRP.JO', 'HDC.JO', 'BID.JO', 'EXP.JO', 'SOH.JO', 'CMO.JO', 'EMH.JO', 'CKS.JO', 'VOD.JO', 'SPP.JO', 'QLT.JO', 'COH.JO', 'NWL.JO', 'DCP.JO', 'SHP.JO', 'SHG.JO', 'SOLBE1.JO', 'IMP.JO', 'ELI.JO', 'REA.JO', 'ORN.JO', 'YYLBEE.JO', 'LNF.JO', 'SBKP.JO', 'AEG.JO', 'ANH.JO', 'MPT.JO', 'TCP.JO', 'MNP.JO', 'MST.JO', 'TEX.JO', 'YRK.JO', 'INP.JO', 'TON.JO', 'EMI.JO', 'SEP.JO', 'RACP.JO', 'GND.JO', 'TRL.JO', 'ACT.JO', 'RLO.JO', 'LHC.JO', 'BCF.JO', 'DLT.JO', 'OMU.JO', 'THA.JO', 'AON.JO', 'DSY.JO', 'SAR.JO', 'NVS.JO', 'RDF.JO', 'OMN.JO', 'PAN.JO', 'PPC.JO', 'CGR.JO']
# tickers
# 1    REB.JO
# 0    GRT.JO
# 1    REB.JO
# 2    KST.JO
# 3    WEZ.JO
# 4    RHB.JO
# ..      ...
# 252  RDF.JO
# 253  OMN.JO
# 254  PAN.JO
# 255  PPC.JO
# 256  CGR.JO
#
# [257 rows x 1 columns]

# %%
df3 = pd.read_csv('/content/Stocks_final3/ABG.JO.csv')
df3.info()
df3

# %%
df4 = pd.read_csv('/content/jsestocks/ABG.JO.csv')
df4.info()
df4

# %%
'''
#Import required libraries
import pandas as pd
import json
import requests
import glob
import os
from yahooquery import Ticker
from datetime import datetime
'''
now = datetime.now().strftime("%Y-%m-%d")
data = yf.Ticker("STXCAP.JO")
index = data.history(start=start,  end=end)
resetindex = index.reset_index(inplace = True)

index['Date'] = pd.to_datetime(index['Date']).dt.strftime('%Y-%m-%d')

index = index.drop(columns=(['Open', 'High','Low','Volume','Dividends','Stock Splits']))

index.set_index("Date", inplace=True)

index.to_csv(index_date)
STX = pd.read_csv(index_date,index_col='Date', parse_dates=['Date'])
STX['SMA'] = STX['Close'].rolling(200).mean()
STX.plot()
STX['diff'] = STX['Close'] - STX['SMA']
print(STX.tail(1))
'''

params = {'access_key': 'e52cf3b93696352e880916f8c8adbf0c',
          'limit': 350}
api_result = requests.get('http://api.marketstack.com/v1/exchanges/XJSE/tickers', params)
api_response = api_result.json()
print(f"Exchange Name = {api_response['data']['name']}")
for ticker in api_response['data']['tickers']:
  print(f"{ticker['name']}: {ticker['symbol']}")


# Serializing json
json_object = json.dumps(api_response, indent=4)
# Writing to sample.json
with open("jse.json", "w") as outfile:
    outfile.write(json_object)
'''
import pandas as pd
import json

# Opening JSON file
with open('jse.json', 'r') as openfile:
    # Reading from json file
    json_object = json.load(openfile)
df1 = pd.json_normalize(json_object["data"]["tickers"])

# dropping null value columns to avoid errors
# new data frame with split value columns
new = df1["symbol"].str.split(".", n = 1, expand = True)
# making separate first name column from new data frame
df1["ticker"]= new[0]
# Dropping old Name columns
df1.drop(columns =["has_intraday","has_eod"], inplace = True)
new.columns = new.columns.astype(str)
new.columns.values[1] = "tickers"
new['0'] + '.' + new['tickers']
new.replace("XJSE", "JO", inplace=True)

result = pd.concat([df1, new], axis=1, join='inner')
df2=result['0'] + '.' + result['tickers']

'''
final = pd.concat([df1, df2], axis=1, join='inner')
final.columns.values[3] = "tickers"
final.columns = final.columns.astype(str)
#Dropping old Name columns
final.drop(columns =["name", "symbol","ticker"], inplace = True)
# Converting a specific Dataframe
# column to list using Series.tolist()
xjse = final["tickers"].tolist()
print("Converting tickers to list...")
print("Output dataframe..." )
print("Writing csv file..." )
print("Saving JSE data to disc...")
print("Saving csv files for each stock to disc...")
symbols = xjse
tickers = Ticker(symbols, asynchronous=True)
data = tickers.history(start= start, end=end, interval='1d')
data= data.drop(['adjclose','dividends','splits'],axis=1)


#Convert dataframe to csv and save to disc
final.to_csv("tickers.csv")
data.to_csv("jse_stocks.csv")

resetindex = data.reset_index(inplace = True)

for i, g in data.groupby('symbol'):
    g.to_csv('/content/Stocks/{}.csv'.format(i), header=True, index_label=False)

# merging the files
joined_files = os.path.join("/content/Stocks/", "*.csv")

# A list of all joined files is returned
joined_list = glob.glob(joined_files)

# Finally, the files are joined
df = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)

# new dataframe with different column order
df_new = df.iloc[:, [1, 2, 3, 4, 5, 6, 0]]

Tickers = df_new["symbol"].tolist()
mylist = list(dict.fromkeys(Tickers))
df = pd.DataFrame (mylist, columns = ['tickers'])
df.to_csv("/content/tickers.csv")

#Change date format to Year-Month-Day
df_new['date'] =  pd.to_datetime(df_new['date']).dt.strftime('%Y-%m-%d')

df_new.set_index('date', inplace=True)

for i, g in df_new.groupby('symbol'):
    g.to_csv('/content/Stocks_final3/{}.csv'.format(i), header=True, index_label=False)

symbols = xjse
tickers = Ticker(symbols, asynchronous=True)
data = tickers.history(start=start, end=end, interval='1d')
data= data.drop(['adjclose','dividends','splits'],axis=1)

resetindex = data.reset_index(inplace = True)

# new dataframe with different column order
df_new = data.iloc[:, [1, 2, 3, 4, 5, 6, 0]]

Tickers = df_new["symbol"].tolist()
mylist = list(dict.fromkeys(Tickers))
df = pd.DataFrame (mylist, columns = ['tickers'])
df.columns = df.iloc[1]

df.to_csv("/content/Stocks_final3/tickers.csv")


csv_folder = Path('/content/Stocks_final3')

for file in csv_folder.glob('*.JO.csv'): #create iteratable & iterate on it.
    mydata = pd.read_csv(file)
    mydata.reset_index(inplace = True)
    mydata = mydata.rename(columns={'index': 'date'}, index=None)
    mydata['date'] =  pd.to_datetime(mydata['date']).dt.strftime('%Y-%m-%d')
    mydata.set_index('date', inplace=True)
    df =mydata[["open","high","low","close","volume"]]
    no_outlier_prices = df[(np.abs(stats.zscore(df)) <3).all(axis=1)]
    new_file_name = file.parent.joinpath(f"{file.stem}.csv")
    no_outlier_prices.to_csv(new_file_name) #, index=None, encoding='utf-8-sig', decimal=',')
'''
# Out:
#              Close          SMA        diff
# Date
# 2024-07-03  4056.0  3687.944316  368.055684
# '\nfinal = pd.concat([df1, df2], axis=1, join=\'inner\')\nfinal.columns.values[3] = "tickers"\nfinal.columns = final.columns.astype(str)\n#Dropping old Name columns\nfinal.drop(columns =["name", "symbol","ticker"], inplace = True)\n# Converting a specific Dataframe\n# column to list using Series.tolist()\nxjse = final["tickers"].tolist()\nprint("Converting tickers to list...")\nprint("Output dataframe..." )\nprint("Writing csv file..." )\nprint("Saving JSE data to disc...")\nprint("Saving csv files for each stock to disc...")\nsymbols = xjse\ntickers = Ticker(symbols, asynchronous=True)\ndata = tickers.history(start= start, end=end, interval=\'1d\')\ndata= data.drop([\'adjclose\',\'dividends\',\'splits\'],axis=1)\n\n\n#Convert dataframe to csv and save to disc\nfinal.to_csv("tickers.csv")\ndata.to_csv("jse_stocks.csv")\n\nresetindex = data.reset_index(inplace = True)\n\nfor i, g in data.groupby(\'symbol\'):\n    g.to_csv(\'/content/Stocks/{}.csv\'.format(i), header=True, index_label=False)\n\n# merging the files\njoined_files = os.path.join("/content/Stocks/", "*.csv")\n\n# A list of all joined files is returned\njoined_list = glob.glob(joined_files)\n\n# Finally, the files are joined\ndf = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)\n\n# new dataframe with different column order\ndf_new = df.iloc[:, [1, 2, 3, 4, 5, 6, 0]]\n\nTickers = df_new["symbol"].tolist()\nmylist = list(dict.fromkeys(Tickers))\ndf = pd.DataFrame (mylist, columns = [\'tickers\'])\ndf.to_csv("/content/tickers.csv")\n\n#Change date format to Year-Month-Day\ndf_new[\'date\'] =  pd.to_datetime(df_new[\'date\']).dt.strftime(\'%Y-%m-%d\')\n\ndf_new.set_index(\'date\', inplace=True)\n\nfor i, g in df_new.groupby(\'symbol\'):\n    g.to_csv(\'/content/Stocks_final3/{}.csv\'.format(i), header=True, index_label=False)\n\nsymbols = xjse\ntickers = Ticker(symbols, asynchronous=True)\ndata = tickers.history(start=start, end=end, interval=\'1d\')\ndata= data.drop([\'adjclose\',\'dividends\',\'splits\'],axis=1)\n\nresetindex = data.reset_index(inplace = True)\n\n# new dataframe with different column order\ndf_new = data.iloc[:, [1, 2, 3, 4, 5, 6, 0]]\n\nTickers = df_new["symbol"].tolist()\nmylist = list(dict.fromkeys(Tickers))\ndf = pd.DataFrame (mylist, columns = [\'tickers\'])\ndf.columns = df.iloc[1]\n\ndf.to_csv("/content/Stocks_final3/tickers.csv")\n\n\ncsv_folder = Path(\'/content/Stocks_final3\')\n\nfor file in csv_folder.glob(\'*.JO.csv\'): #create iteratable & iterate on it.\n    mydata = pd.read_csv(file)\n    mydata.reset_index(inplace = True)\n    mydata = mydata.rename(columns={\'index\': \'date\'}, index=None)\n    mydata[\'date\'] =  pd.to_datetime(mydata[\'date\']).dt.strftime(\'%Y-%m-%d\')\n    mydata.set_index(\'date\', inplace=True)\n    df =mydata[["open","high","low","close","volume"]]\n    no_outlier_prices = df[(np.abs(stats.zscore(df)) <3).all(axis=1)]\n    new_file_name = file.parent.joinpath(f"{file.stem}.csv")\n    no_outlier_prices.to_csv(new_file_name) #, index=None, encoding=\'utf-8-sig\', decimal=\',\')\n'

# %% [markdown]
# ###Indicators

# %%
# %matplotlib inline

import os
from pathlib import Path
from datetime import datetime
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import stockstats
from stockstats import StockDataFrame as sdf


plt.rcParams["figure.figsize"] = (12, 9) # (w, h)
plt.ioff()

tickers = pd.read_csv('/content/jsestocks/tickers.csv', header=None)[1].tolist()
stocks = (
    (pd.concat(
        [pd.read_csv(f"/content/jsestocks/{ticker}.csv",parse_dates=None, index_col=0)[
        'close'].rename(ticker)
        for ticker in tickers],
        axis=1,
        sort=True)
    )
)
stocks = stocks.loc[:,~stocks.columns.duplicated()]

from scipy.stats import linregress
def momentum(closes):
    returns = np.log(closes)
    x = np.arange(len(returns))
    slope, _, rvalue, _, _ = linregress(x, returns)
    return ((1 + slope) ** 252) * (rvalue ** 2)  # annualize slope and multiply by R^2

momentums = stocks.copy(deep=True)
for ticker in tickers:
    momentums[ticker] = stocks[ticker].rolling(90).apply(momentum, raw=False)

result = momentums.sort_values(by =ranking_day, axis = 1, ascending =False)
result.reset_index(inplace=True)
res=result[~(result['date'] < ranking_day)].dropna(axis=1)

mes = res.reindex(columns = res.columns.tolist()
                                  + ['empty'])

df = mes.set_index(['empty']).stack().reset_index(name='index').rename(columns={'level_2':'date'})

df.columns = df.iloc[0]

df.index = list(df.index)

df.columns.values[0] = "empty"
df.columns.values[1] = "symbol"
df.columns.values[2] = "momentum_score"

df=df.drop(['empty'], axis=1)

finalframe=df.drop(index=0)

finalframe['momentum_score'] =finalframe['momentum_score'].astype(float)

finalframe['rank']=finalframe['momentum_score'].rank(ascending=False)

finalframe['momentum_score'] =finalframe['momentum_score'].astype(float)

#finalframe.style.format({'momentum_score':"{:.2f}"})

Mylist = finalframe["symbol"].tolist()

finalframe.set_index('symbol',inplace=True)

final = pd.concat([df1, df2], axis=1, join='inner')
final.columns.values[3] = "tickers"
final.columns = final.columns.astype(str)

final.set_index('tickers', inplace=True)
Yes = final.reindex(Mylist)

rt = pd.concat([finalframe, Yes], axis=1, join='inner')

rt = rt.iloc[:, [2, 3, 4, 0, 1]]

#rt.style.format({'momentum_score':"{:.2f}"})

# get names of indexes for which column "momentum_score" has value > 40%
index_names = rt[(rt['momentum_score'] < 0.001)].index

# drop these given row indexes from dataFrame
rt.drop(index_names, inplace = True)

rt.reset_index(inplace=True)

lowranked = rt [( rt ['rank'] >= 71)].index

# drop these given row indexes from dataFrame
rt.drop( lowranked, inplace = True)

My_final_list = rt["index"].tolist()

rt.set_index('index',inplace=True)

rt.to_csv(ranking_table)
final_table_columns = My_final_list
final_table =stocks.drop(columns=[col for col in stocks if col not in final_table_columns])

for column in final_table.columns:
    final_table[column].to_csv('/content/momentum_tickers/' + column + '.csv')

vola_table = Path('/content/momentum_tickers')

for file in vola_table.glob('*.JO.csv'): #create iteratable & iterate on it.
    vola_df = pd.read_csv(file)
    vola_df.columns.values[1] = "close"
    vola_df["20d_vol"] = vola_df["close"].pct_change().rolling(20).std()
    #vola_df = sdf.retype(vola_df)['close_90_roc']
    vola_df = pd.DataFrame(vola_df)
    vola_df['date'] =  pd.to_datetime(vola_df['date']).dt.strftime('%Y-%m-%d')
    vola_df['close_90_roc'] = (vola_df['close'] / vola_df['close'].shift(1) - 1).fillna(0)
    vola_df.set_index('date', inplace=True)
    #stockstats_df = sdf.retype(vola_df)['close_90_roc']
    #df = pd.DataFrame(stockstats_df)
    vola_file_name= file.parent.joinpath(f"/content/ranking_table/{file.stem}.csv")
    vola_df.to_csv(vola_file_name) #, index=None, encoding='utf-8-sig', decimal=',')

vola_table1 = Path('/content/ranking_table')

for file in vola_table1.glob('*.JO.csv'): #create iteratable & iterate on it.
    vola_df1 = pd.read_csv(file).tail(1)

    vola_df1['date'] =  pd.to_datetime(vola_df1['date']).dt.strftime('%Y-%m-%d')

    vola_df1.set_index('date', inplace=True)

    vola_file_name1= file.parent.joinpath(f"/content/momentum_stocks/{file.stem}.csv")

    vola_df1.to_csv(vola_file_name1)


# set search path and glob for files
# here we want to look for csv files in the input directory
path = '/content/'
files = glob.glob(path + '/momentum_stocks/*.csv')

# create empty list to store dataframes
li = []

# loop through list of files and read each one into a dataframe and append to list
for f in files:
    # get filename
    stock = os.path.basename(f)
    # read in csv
    temp_df = pd.read_csv(f)
    # create new column with filename
    temp_df['ticker'] = stock
    # data cleaning to remove the .csv
    temp_df['ticker'] = temp_df['ticker'].replace('.csv', '', regex=True)
    # append df to list
    li.append(temp_df)
    #print(f'Successfully created dataframe for {stock} with shape {temp_df.shape}')

# concatenate our list of dataframes into one!
df = pd.concat(li)

ranking_list =df.set_index('ticker').reindex(My_final_list).reset_index()

inv_vol = 1 / ranking_list["20d_vol"]
sum_inv_vol=inv_vol.sum()
vol_targets = inv_vol / sum_inv_vol
ranking_list["weight"] = vol_targets

ranking_list.set_index('ticker', inplace=True)

final_list = pd.concat([rt,ranking_list], axis=1, join='inner')

stockprice = final_list["close"] / 100
pos_weight = portfolio_value * final_list["weight"]
final_list["units"] = pos_weight / stockprice
final_list["ZAR"] = stockprice * final_list["units"]


sma = Path('/content/ranking_table')

for file in sma.glob('*.JO.csv'): #create iteratable & iterate on it.
    sma = pd.read_csv(file)
    sma['date'] =  pd.to_datetime(sma['date']).dt.strftime('%Y-%m-%d')
    sma.set_index('date', inplace=True)

    '''Function'''

    sma['100d_sma'] = sma['close'].rolling(100).mean()

    #sma['index_sma']=index['Close'].rolling(200).mean()

    #sma['trend'] = np.where(sma['close'] > sma['100d_sma'], True, False)

    sma['index'] = index['Close']

    sma['index_sma']=index['Close'].rolling(200).mean()

    sma['trend'] = np.where(sma['close'] > sma['100d_sma'], True, False)

    sma['index_trend']= np.where(sma['index'] > sma['index_sma'], True, False)

    sma_file_name= file.parent.joinpath(f"/content/sma_data/{file.stem}.csv")

    sma.to_csv(sma_file_name)

buy_table = Path('/content/sma_data')

for file in buy_table.glob('*.JO.csv'): #create iteratable & iterate on it.
    buy_list_df = pd.read_csv(file).tail(1)

    buytable = file.parent.joinpath(f"/content/buy_list/{file.stem}.csv")

    buy_list_df.to_csv(buytable)
# Out:
# <ipython-input-14-75bb3a51883d>:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   result.reset_index(inplace=True)

# %% [markdown]
# ###Initial Portfolio and Ranking Table

# %%
import pandas as pd
import glob

# set search path and glob for files
# here we want to look for csv files in the input directory
path1 = '/content/'
files1 = glob.glob(path1 + '/buy_list/*.csv')

# create empty list to store dataframes
li1 = []

# loop through list of files and read each one into a dataframe and append to list
for f1 in files1:
    # get filename
    stock1 = os.path.basename(f1)
    # read in csv
    temp_df1 = pd.read_csv(f1)
    # create new column with filename
    temp_df1['ticker'] = stock1
    # data cleaning to remove the .csv
    temp_df1['ticker'] = temp_df1['ticker'].replace('.csv', '', regex=True)
    # append df to list
    li1.append(temp_df1)
    #print(f'Successfully created dataframe for {stock1} with shape {temp_df1.shape}')

# concatenate our list of dataframes into one!
Buy = pd.concat(li1)

buying_list = Buy.set_index('ticker').reindex(My_final_list)#.reset_index()

final_buy_list = pd.concat([final_list, buying_list], axis=1, join='inner')

#define list of columns range
cols = [x for x in range(final_buy_list.shape[1])]

#remove second column in DataFrame
cols.remove(12)
cols.remove(13)
cols.remove(14)
cols.remove(15)
cols.remove(16)#view resulting DataFrame
final_buy_list2 =final_buy_list.iloc[:, cols]
final_buy_list2.info()

final_buy_list2 = final_buy_list2.loc[final_buy_list2.trend, :]

index_names1 = final_buy_list2[(final_buy_list2['close_90_roc'] >= 15)].index

# drop these given row indexes from dataFrame
final_buy_list2.drop(index_names1, inplace = True)
final_buy_list2.to_csv(portfolio)
#final_buy_list2
'''
final_buy_list2.ticker = final_buy_list2.ticker+ '.JO'
Tickers = final_buy_list2["ticker"].tolist()
sector_list=[]

for tik in Tickers:
    ticker=yf.Ticker(tik)
    sector=ticker.info['sector']
    sector_list.append(sector)

final_buy_list2['sector'] = sector_list
'''
rp_units= final_buy_list2["units"].sum()
rp_weights = final_buy_list2["weight"].sum()
rp_holdings_value= final_buy_list2["ZAR"].sum()
cash_holdings_rp = portfolio_value - rp_holdings_value

print(f"FRP total units = {rp_units}")
print(f"FRP total units = {rp_weights}")
print(f"FRP holdings value = {rp_holdings_value}")
print(f"RP cash value = {cash_holdings_rp}")
pct_cash_rp = cash_holdings_rp / portfolio_value

final_buy_list2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, RHB.JO to GRT.JO
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            21 non-null     object
#  1   symbol          21 non-null     object
#  2   ticker          21 non-null     object
#  3   momentum_score  21 non-null     float64
#  4   rank            21 non-null     float64
#  5   date            21 non-null     object
#  6   close           21 non-null     float64
#  7   20d_vol         21 non-null     float64
#  8   close_90_roc    21 non-null     float64
#  9   weight          21 non-null     float64
#  10  units           21 non-null     float64
#  11  ZAR             21 non-null     float64
#  12  100d_sma        20 non-null     float64
#  13  index           21 non-null     float64
#  14  index_sma       21 non-null     float64
#  15  trend           21 non-null     bool
#  16  index_trend     21 non-null     bool
# dtypes: bool(2), float64(11), object(4)
# memory usage: 3.2+ KB
# FRP total units = 21069.966327980375
# FRP total units = 0.8143062259562154
# FRP holdings value = 126351.79297824713
# RP cash value = 28813.16702175286
#                               name    symbol ticker  momentum_score  rank  \
# RHB.JO          RH BOPHELO LIMITED  RHB.XJSE    RHB       11.239658   1.0
# TEX.JO    TEXTON PROPERTY FUND LTD  TEX.XJSE    TEX        2.204212   2.0
# ARI.JO     AFRICAN RAINBOW MIN LTD  ARI.XJSE    ARI        2.172348   3.0
# NVS.JO      NOVUS HOLDINGS LIMITED  NVS.XJSE    NVS        2.084477   4.0
# AEL.JO   ALLIED ELECTRONICS CORP A  AEL.XJSE    AEL        1.861331   5.0
# TRL.JO         TRELLIDOR HLDGS LTD  TRL.XJSE    TRL        1.332300   6.0
# HAR.JO           HARMONY GM CO LTD  HAR.XJSE    HAR        1.215167   7.0
# MRP.JO          MR PRICE GROUP LTD  MRP.XJSE    MRP        0.818105   8.0
# AFH.JO  ALEXANDER FORBES GRP HLDGS  AFH.XJSE    AFH        0.670947   9.0
# MMP.JO      MARSHALL MONTEAGLE PLC  MMP.XJSE    MMP        0.609153  10.0
# SNV.JO       SANTOVA LOGISTICS LTD  SNV.XJSE    SNV        0.546002  12.0
# DCP.JO     DIS-CHEM PHARMACIES LTD  DCP.XJSE    DCP        0.423967  13.0
# YRK.JO    YORK TIMBER HOLDINGS LTD  YRK.XJSE    YRK        0.322059  14.0
# BLU.JO     BLUE LABEL TELECOMS LTD  BLU.XJSE    BLU        0.264843  16.0
# GML.JO     GEMFIELDS GROUP LIMITED  GML.XJSE    GML        0.075683  18.0
# TPC.JO               TRANSPACO LTD  TPC.XJSE    TPC        0.033819  19.0
# GRT.JO        GROWTHPOINT PROP LTD  GRT.XJSE    GRT        0.001907  21.0
#
#               date    close   20d_vol  close_90_roc    weight        units  \
# RHB.JO  2024-07-03    289.0  0.070581      0.000000  0.016832   903.702856
# TEX.JO  2024-07-03    325.0  0.013282     -0.018127  0.089445  4270.384713
# ARI.JO  2024-07-03  23644.0  0.024456      0.086431  0.048578    31.879304
# NVS.JO  2024-07-03    575.0  0.040024     -0.018771  0.029682   800.986934
# AEL.JO  2024-07-03   1410.0  0.039141      0.000000  0.030352   334.012715
# TRL.JO  2024-07-03    190.0  0.083313      0.151515  0.014260  1164.513522
# HAR.JO  2024-07-03  17416.0  0.025571      0.009331  0.046459    41.391857
# MRP.JO  2024-07-03  20750.0  0.028984      0.012195  0.040987    30.649751
# AFH.JO  2024-07-03    718.0  0.041091      0.001395  0.028912   624.798763
# MMP.JO  2024-07-03   2850.0  0.013300      0.000000  0.089325   486.321052
# SNV.JO  2024-07-03    770.0  0.016035     -0.016603  0.074085  1492.918583
# DCP.JO  2024-07-03   3420.0  0.020832      0.020896  0.057026   258.728137
# YRK.JO  2024-07-03    182.0  0.019291      0.052023  0.061582  5250.233913
# BLU.JO  2024-07-03    405.0  0.018341      0.022727  0.064772  2481.568329
# GML.JO  2024-07-03    292.0  0.030943      0.010381  0.038393  2040.171973
# TPC.JO  2024-07-03   3385.0  0.045758      0.000296  0.025963   119.010362
# GRT.JO  2024-07-03   1211.0  0.020606      0.004146  0.057652   738.693566
#
#                  ZAR    100d_sma   index    index_sma  trend  index_trend
# RHB.JO   2611.701252    268.2402  4056.0  3687.944316   True         True
# TEX.JO  13878.750316    291.2600  4056.0  3687.944316   True         True
# ARI.JO   7537.542585  19617.1100  4056.0  3687.944316   True         True
# NVS.JO   4605.674871    465.0300  4056.0  3687.944316   True         True
# AEL.JO   4709.579279   1158.5100  4056.0  3687.944316   True         True
# TRL.JO   2212.575692    155.6100  4056.0  3687.944316   True         True
# HAR.JO   7208.805821  15335.9500  4056.0  3687.944316   True         True
# MRP.JO   6359.823242  17788.5100  4056.0  3687.944316   True         True
# AFH.JO   4486.055116    652.1900  4056.0  3687.944316   True         True
# MMP.JO  13860.149977   2812.6900  4056.0  3687.944316   True         True
# SNV.JO  11495.473089    742.6100  4056.0  3687.944316   True         True
# DCP.JO   8848.502291   3217.6600  4056.0  3687.944316   True         True
# YRK.JO   9555.425722    168.8100  4056.0  3687.944316   True         True
# BLU.JO  10050.351731    404.5100  4056.0  3687.944316   True         True
# GML.JO   5957.302161    288.2100  4056.0  3687.944316   True         True
# TPC.JO   4028.500744   3092.9700  4056.0  3687.944316   True         True
# GRT.JO   8945.579089   1136.7000  4056.0  3687.944316   True         True

# %% [markdown]
# ###List to Liquidate current positions

# %%
sell_list = final_buy_list [~final_buy_list
 ["trend"]]
#sell_list.info()
dqs = sell_list ["ticker"].tolist()
cpf=pd.read_csv(current_portfolio)
#sell_list
liquidate = cpf.loc[cpf['ticker'].isin (dqs)].reset_index (drop=True)

newpf = cpf[~cpf['ticker'].isin(liquidate['ticker'])]
dfnew = newpf[~newpf['ticker'].isin(final_buy_list2['ticker'])]

remove = dfnew ["ticker"].tolist()
now = newpf[~newpf['ticker'].isin(dfnew['ticker'])]
now.set_index("ticker", inplace=True)
rebalance = now ["symbol"].tolist()

print(f"Liquidate disqualified stocks = {liquidate['name']}")
print(f"Liquidate stocks not in ranking table= {dfnew['name']}")
print(f"Portfolio after liquidation= {now['name']}")

# %%
cpf

# %% [markdown]
# ###Update Ranking Table

# %%
portfolio_value2 = 156560.00

final_weights = final_buy_list
final_weights.set_index('rank').reset_index()
final_w = [x for x in range(final_weights.shape[1])]

final_w.remove(12)
final_w.remove(13)
final_w.remove(14)
final_w.remove(15)
final_w.remove(16)
final_weights2=final_weights.iloc[:, cols]
inv_vol2 = 1 / final_weights2["20d_vol"]
sum_inv_vol2 =inv_vol2.sum()
vol_targets2 = inv_vol2 / sum_inv_vol2
final_weights2["weight"] = vol_targets2

final_weights2.set_index('symbol', inplace=True)

stockprice2 = final_weights2["close"] / 100
pos_weight2 = portfolio_value2 * final_weights2["weight"]
final_weights2["units"] = pos_weight2 / stockprice2
final_weights2["ZAR"] = stockprice2 * final_weights2["units"]
final_weights2.to_csv(ranking_table)
final_weights2

# %% [markdown]
# ###Rebalance Positions

# %%
rebalance1 =final_weights2[final_weights2['name'].isin(now['name'])]

index_names4 = rebalance1 [( rebalance1 ['rank'] >= 71)].index

# drop these given row indexes from dataFrame
Allsale =rebalance1.drop(index_names4)

rebalance3 = rebalance1.reindex(rebalance).set_index('ticker')


now.reset_index(inplace=True)
rebalance3.reset_index(inplace=True)

rebalance3 ["bs"] = rebalance3["units"]-now["units"]
index_names5 = rebalance3 [( rebalance3 ['rank'] >= 71)].index

# drop these given row indexes from dataFrame
rebalance3.drop(index_names5, inplace = True)
rebalance3

# %% [markdown]
# ###Enter New Positions

# %%
ranking_table1 = final_weights2.reindex().set_index('ticker')
#ranking_table1["bs"] = ranking_table1["units"] * 1
ranking_table1.reset_index(inplace=True)

ranking_table1 = ranking_table1.loc[ranking_table1.trend, :]
index_names2 = ranking_table1 [( ranking_table1 ['close_90_roc'] >= 15)].index

# drop these given row indexes from dataFrame
ranking_table1.drop(index_names2, inplace = True)

buynew = ranking_table1 [~ ranking_table1 ['ticker'].isin( rebalance3 ['ticker'])]
index_names2 = ranking_table1 [( ranking_table1 ['close_90_roc'] >= 15)].index

# drop these given row indexes from dataFrame
ranking_table1.drop(index_names2, inplace = True)

buynamesnew2 = buynew [( buynew ['rank'] >= 71)].index

# drop these given row indexes from dataFrame
buynew.drop( buynamesnew2, inplace = True)

buynew

# %% [markdown]
# ###Portfolio after position rebalance

# %%
rebalancex = rebalance3.reset_index().set_index("level_0")
buynewx = buynew.reset_index().set_index("level_0")
new_portfolio2 = rebalancex.append(buynewx, ignore_index=True)
new_portfolio2.drop(columns =["bs"], inplace = True)

rslt_df = new_portfolio2.sort_values(by = 'rank', ascending = True)
'''
rslt_df .ticker = rslt_df.ticker+ '.JO'
Tickers = rslt_df["ticker"].tolist()
sector_list=[]

for tik in Tickers:
    ticker=yf.Ticker(tik)
    sector=ticker.info['sector']
    sector_list.append(sector)

rslt_df ['sector'] = sector_list
'''
frp_units=rslt_df["units"].sum()
frp_weights = rslt_df["weight"].sum()
frp_holdings_value=rslt_df["ZAR"].sum()
cash_holdings_frp = portfolio_value2 - frp_holdings_value
pct_cash_frp = cash_holdings_frp / portfolio_value2

print(f"FRP total units = {frp_units}")
print(f"FRP total units = {frp_weights}")
print(f"FRP holdings value = {frp_holdings_value}")
print(f"FRP cash value = {cash_holdings_frp}")

rslt_df

# %% [markdown]
# ###Portfolio after rebalance

# %%
Xxx = now[now['name'].isin(final_buy_list2['name'])]
Xxx2 = Xxx.reset_index().set_index("level_0")
buynewx = buynew.reset_index().set_index("level_0")
new_portfolio3 = Xxx2.append(buynewx, ignore_index=True)
rslt_df2 = new_portfolio3.sort_values(by = 'rank', ascending = True)
inv_vol = 1 / rslt_df2["20d_vol"]
rslt_df2["weight"] = rslt_df2 ["ZAR"] / portfolio_value2
rslt_df2.set_index('rank', inplace=True)
rslt_df2.drop(columns =["symbol"], inplace = True)
'''

rslt_df2 .ticker = rslt_df2.ticker+ '.JO'
Tickers = rslt_df2["ticker"].tolist()
sector_list=[]

for tik in Tickers:
    ticker=yf.Ticker(tik)
    sector=ticker.info['sector']
    sector_list.append(sector)

rslt_df2 ['sector'] = sector_list
'''
rp_units=rslt_df2["units"].sum()
rp_weights = rslt_df2["weight"].sum()
rp_holdings_value=rslt_df2["ZAR"].sum()
cash_holdings_rp = portfolio_value2 - rp_holdings_value

print(f"FRP total units = {rp_units}")
print(f"FRP total units = {rp_weights}")
print(f"FRP holdings value = {rp_holdings_value}")
print(f"RP cash value = {cash_holdings_rp}")
pct_cash_rp = cash_holdings_rp / portfolio_value2

rslt_df2

# %% [markdown]
# #Test

# %%
final_buy_list2.ticker = final_buy_list2.ticker+ '.JO'
Tickers = final_buy_list2["ticker"].tolist()

# %%
import yfinance as yf
import pandas as pd

df = pd.DataFrame()
for stock in Tickers :
  info = yf.Ticker(stock).info
  #industry = info.get('industry')
  #beta = info.get('beta')
  sector = info.get('sector')
  df = df.append({'Stock':stock, 'Sector':sector}, ignore_index=True)

df

# %%
final_buy_list2.set_index('ticker', inplace=True)
df.set_index('Stock', inplace=True)
f_column = df["Sector"]
data1 = pd.concat([final_buy_list2 ,df], axis = 1)
data1

# %%
data1['weight'].sum()

# %%
new_dataset = data1.loc[:, ['Sector','weight']]
#new_dataset.set_index("Sector",inplace=True)
new_dataset.loc[len(new_dataset.index)] = ['Cash', pct_cash_frp]
new_dataset

# %%
new_dataset["weight"].sum()

# %%
new_dataset.groupby(['Sector']).sum().plot(kind='pie', y='weight', autopct='%1.0f%%')

plt.tight_layout()

# We save the graph in jpg format
plt.savefig("my_graph.jpg")
plt.show()

# %%
dataset = new_dataset
# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(dataset).mark_bar().encode(
  x='sum(weight)',
  y='Sector',
  color='Sector'
)

# %%
RankingTable08092023 = pd.read_csv("/content/ranking_table130923.csv")
RankingTable08092023

# %%
Portfolio = pd.read_csv("/content/portfolio130923.csv")
Portfolio
